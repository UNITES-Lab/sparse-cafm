# %%
import pandas as pd
from glob import glob

evals_dir = "/playpen/mufan/levi/tianlong-chen-lab/material-super-resolution/__exps__/y-task-formulations/p(y | y_sparse)/b. evals"
dirs = glob(f"{evals_dir}/*02-20*")
dirs.sort()

# %%
import matplotlib.pyplot as plt

exp_names = [s.split("02-20_")[-1] for s in dirs]; exp_names
exp_results = [glob(d + "/*.csv")[0] for d in dirs]; exp_results

for name, result in zip(exp_names, exp_results):
    assert name in result
    df = pd.read_csv(result)
    summary_stats = {
    "MAE": df["mae"].mean(),
    "MSE": df["mse"].mean(),
    "PSNR": df["psnr"].mean(),
    "SSIM": df["ssim"].mean(),
    "OLDER": df["older"].mean(),
    }
    summary_str = "\n".join([f"{key}: {value:.6f}" for key, value in summary_stats.items()])
    print(f"{name} stats:\n" + summary_str)
    print("------------------------------")
# Out:
# 15-09-14_SwinIR-loss=OLDER-Perceptual-VGG-19-NEW(raw-out, y) stats:
# MAE: 0.010969
# MSE: 0.000487
# PSNR: 33.943816
# SSIM: 0.888446
# OLDER: 0.295525
# ------------------------------
# 15-09-15_SwinIR-loss=OLDER-Perc-NEW-VGG+L1(raw-out, y)-lambda=1e-0 stats:
# MAE: 0.010077
# MSE: 0.000456
# PSNR: 34.484574
# SSIM: 0.900658
# OLDER: 0.287462
# ------------------------------
# 15-09-15_SwinIR-loss=OLDER-Perc-NEW-VGG+L1(raw-out, y)-lambda=1e-1 stats:
# MAE: 0.010039
# MSE: 0.000450
# PSNR: 34.480127
# SSIM: 0.900728
# OLDER: 0.270849
# ------------------------------
# 15-09-15_SwinIR-loss=OLDER-Perc-NEW-VGG+L1(raw-out, y)-lambda=1e-2 stats:
# MAE: 0.010141
# MSE: 0.000461
# PSNR: 34.381879
# SSIM: 0.899428
# OLDER: 0.270444
# ------------------------------
# 15-09-15_SwinIR-loss=OLDER-Perc-NEW-VGG+L1(raw-out, y)-lambda=1e-3 stats:
# MAE: 0.010245
# MSE: 0.000467
# PSNR: 34.321933
# SSIM: 0.898584
# OLDER: 0.292678
# ------------------------------
# 15-09-15_SwinIR-loss=OLDER-Perc-NEW-VGG+L1(raw-out, y)-lambda=1e-4 stats:
# MAE: 0.010087
# MSE: 0.000452
# PSNR: 34.438824
# SSIM: 0.900237
# OLDER: 0.276750
# ------------------------------
# 15-09-15_SwinIR-loss=OLDER-Perc-NEW-VGG+L1(raw-out, y)-lambda=1e-5 stats:
# MAE: 0.010055
# MSE: 0.000450
# PSNR: 34.470901
# SSIM: 0.900629
# OLDER: 0.271322
# ------------------------------
# 15-09-15_SwinIR-loss=OLDER-Perc-NEW-VGG+L1(raw-out, y)-lambda=1e-6 stats:
# MAE: 0.010139
# MSE: 0.000456
# PSNR: 34.391118
# SSIM: 0.899420
# OLDER: 0.268713
# ------------------------------
# 15-09-15_SwinIR-loss=OLDER-Perc-NEW-VGG+L1(raw-out, y)-lambda=1e-7 stats:
# MAE: 0.010133
# MSE: 0.000454
# PSNR: 34.399812
# SSIM: 0.899496
# OLDER: 0.274119
# ------------------------------
# 15-09-15_SwinIR-loss=OLDER-Perc-NEW-VGG+L1(raw-out, y)-lambda=1e-8 stats:
# MAE: 0.010143
# MSE: 0.000458
# PSNR: 34.388732
# SSIM: 0.899587
# OLDER: 0.275824
# ------------------------------
# 16-26-53_SwinIR-loss=L1(raw-out, y) stats:
# MAE: 0.009956
# MSE: 0.000442
# PSNR: 34.579618
# SSIM: 0.901242
# OLDER: 0.416549
# ------------------------------
# 16-26-53_SwinIR-loss=OLDER-Perceptual-VGG-19(raw-out, y)-vgg_layer=11 stats:
# MAE: 0.009933
# MSE: 0.000440
# PSNR: 34.564383
# SSIM: 0.902701
# OLDER: 0.435814
# ------------------------------
# 16-26-53_SwinIR-loss=OLDER-Perceptual-VGG-19(raw-out, y)-vgg_layer=37 stats:
# MAE: 0.010056
# MSE: 0.000456
# PSNR: 34.434965
# SSIM: 0.899880
# OLDER: 0.456778
# ------------------------------
# 16-26-53_SwinIR-loss=OLDER-Perceptual-VGG-19(raw-out, y)-vgg_layer=4 stats:
# MAE: 0.010002
# MSE: 0.000453
# PSNR: 34.458225
# SSIM: 0.901324
# OLDER: 0.410697
# ------------------------------
# 16-26-53_SwinIR-loss=OLDER-Perceptual-VGG-19(raw-out, y)-vgg_layer=50 stats:
# MAE: 0.009937
# MSE: 0.000440
# PSNR: 34.599499
# SSIM: 0.901445
# OLDER: 0.415558
# ------------------------------
# 16-26-53_SwinIR-loss=OLDER-VGG-19(raw-out, y)-vgg_layer=last stats:
# MAE: 0.055311
# MSE: 0.014469
# PSNR: 21.800170
# SSIM: 0.511867
# OLDER: 0.905080
# ------------------------------
# 16-26-53_SwinIR-loss=OLDER-VGG-19(raw-out, y)-vgg_layers={4, 11, 24, 37, 50} stats:
# MAE: 0.009875
# MSE: 0.000431
# PSNR: 34.682582
# SSIM: 0.903746
# OLDER: 0.437545
# ------------------------------
# 16-26-54_SwinIR-loss=OLDER-Perceptual-VGG-19(raw-out, y)-vgg_layer=24 stats:
# MAE: 0.009865
# MSE: 0.000430
# PSNR: 34.673331
# SSIM: 0.903207
# OLDER: 0.433059
# ------------------------------
