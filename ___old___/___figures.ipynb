# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from scipy.ndimage import gaussian_filter1d

# %%
MAX_STEPS = 25000

# %% [markdown]
# # **SwinIR [FROZEN] -> UNet [TRAINED]**
# ***

# %%
fp = "/playpen/mufan/levi/tianlong-chen-lab/material-super-resolution/__exps__/y-task-formulations/p(y | y_sparse)/e. surrogate standalone train-runs/2025-02-06_13-59-24_standalone_init_test/results.csv"
df = pd.read_csv(fp)
df.head()
# Out:
#    global_train_step  global_val_step  epoch  train_loss  val_loss   z  \
# 0                0.0              NaN      0         NaN       NaN NaN
# 1                1.0              NaN      0         NaN       NaN NaN
# 2                2.0              NaN      0         NaN       NaN NaN
# 3                3.0              NaN      0         NaN       NaN NaN
# 4                4.0              NaN      0         NaN       NaN NaN
#
#    train_surrogate_loss  val_surrogate_loss
# 0              1.373365                 NaN
# 1              2.476091                 NaN
# 2              1.483635                 NaN
# 3              3.915227                 NaN
# 4              3.672468                 NaN

# %%
SIGMA = 1000

_df = df[df["global_train_step"].notna()]
train_steps = _df["global_train_step"]
train_losses= _df["train_surrogate_loss"]
train_losses = gaussian_filter1d(train_losses, sigma=SIGMA)

# plt.plot(train_steps, train_losses)
plt.plot(train_steps, train_losses)
plt.xlabel("epoch")
plt.ylabel("train_surrogate_loss")
plt.ylim(0, 2)
plt.title("Train Loss vs Epochs")
plt.grid()
plt.show()

# %% [markdown]
# # **Depth=8**
# ***

# %%
fp = "/playpen/mufan/levi/tianlong-chen-lab/material-super-resolution/__exps__/y-task-formulations/p(y | y_sparse)/2025-02-01_10-35-40_swinir-baseline/results.csv"
df = pd.read_csv(fp)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 fp = "/playpen/mufan/levi/tianlong-chen-lab/material-super-resolution/__exps__/y-task-formulations/p(y | y_sparse)/2025-02-01_10-35-40_swinir-baseline/results.csv"
# ----> 2 df = pd.read_csv(fp)
#       3 df.head()
#
# ...

# %%
SIGMA = 300

_df = df[df["global_train_step"].notna()][:MAX_STEPS]
train_steps_depth_8 = _df["global_train_step"]
train_losses_depth_8 = _df["train_loss"]
train_losses_smoothed_depth_8 = gaussian_filter1d(train_losses_depth_8, sigma=SIGMA)

# plt.plot(train_steps, train_losses)
plt.plot(train_steps_depth_8, train_losses_depth_8)
plt.xlabel("epoch")
plt.ylabel("train_loss")
plt.title("Train Loss vs Epochs")
plt.grid()
plt.show()

# %%
_df = df[df["global_val_step"].notna()]

val_steps = _df["global_val_step"].values
val_losses = _df["val_loss"].values
val_losses_smoothed = gaussian_filter1d(val_losses, sigma=SIGMA)

# find lowest point in the smoothed losses
min_index = np.argmin(val_losses_smoothed)
lowest_val_epoch = val_steps[min_index]
lowest_val_loss = val_losses_smoothed[min_index]

# plot smoothed loss
plt.plot(val_steps, val_losses_smoothed)
plt.xlabel("steps")
plt.ylabel("val_loss")
plt.title("Val Loss vs Epoch")
plt.grid(True)

# plot red dot at the lowest loss point
plt.plot(lowest_val_epoch, lowest_val_loss, 'ro', label='Min Loss')
 
# annotate lowest loss value on the figure
plt.annotate(f'Min Loss: {lowest_val_loss:.4f}',
             xy=(lowest_val_epoch, lowest_val_loss), 
             xytext=(lowest_val_epoch, lowest_val_loss), 
             arrowprops=dict(facecolor='black', arrowstyle='->'),
             ha='center')

plt.legend()
plt.show()

# %% [markdown]
# # **Depth=12**
# ---

# %%
fp = "/playpen/mufan/levi/tianlong-chen-lab/material-super-resolution/__exps__/y-task-formulations/p(y | y_sparse)/6a. train-runs/2025-02-01_13-34-55_swinir-depth=12/results.csv"
df = pd.read_csv(fp)

_df = df[df["global_train_step"].notna()][:MAX_STEPS]
train_steps = _df["global_train_step"]
train_losses_depth_12 = _df["train_loss"]
train_losses_smoothed_depth_12 = gaussian_filter1d(train_losses_depth_12, sigma=SIGMA)

# %% [markdown]
# # **Depth=16**
# ---

# %%
fp = "/playpen/mufan/levi/tianlong-chen-lab/material-super-resolution/__exps__/y-task-formulations/p(y | y_sparse)/6a. train-runs/2025-02-01_13-34-55_swinir-depth=16/results.csv"
df = pd.read_csv(fp)
_df = df[df["global_train_step"].notna()][:MAX_STEPS]
train_steps = _df["global_train_step"]
train_losses_depth_16 = _df["train_loss"]
train_losses_smoothed_depth_16 = gaussian_filter1d(train_losses_depth_16, sigma=SIGMA)

# %% [markdown]
# # **Depth=20**
# ---

# %%
fp = "/playpen/mufan/levi/tianlong-chen-lab/material-super-resolution/__exps__/y-task-formulations/p(y | y_sparse)/6a. train-runs/2025-02-01_13-34-55_swinir-depth=20/results.csv"
df = pd.read_csv(fp)

_df = df[df["global_train_step"].notna()][:MAX_STEPS]
train_steps = _df["global_train_step"]
train_losses_depth_20 = _df["train_loss"]
train_losses_smoothed_depth_20 = gaussian_filter1d(train_losses_depth_20, sigma=SIGMA)

# %% [markdown]
# # **Depth=28**
# ---

# %%
fp = "/playpen/mufan/levi/tianlong-chen-lab/material-super-resolution/__exps__/y-task-formulations/p(y | y_sparse)/6a. train-runs/2025-02-01_13-34-56_swinir-depth=28/results.csv"
df = pd.read_csv(fp)

_df = df[df["global_train_step"].notna()][:MAX_STEPS]
train_steps = _df["global_train_step"]
train_losses_depth_28 = _df["train_loss"]
train_losses_smoothed_depth_28 = gaussian_filter1d(train_losses_depth_28, sigma=SIGMA)

# %% [markdown]
# # **Depth=32**
# ***

# %%
fp = "/playpen/mufan/levi/tianlong-chen-lab/material-super-resolution/__exps__/y-task-formulations/p(y | y_sparse)/6a. train-runs/2025-02-01_13-34-55_swinir-depth=32/results.csv"
df = pd.read_csv(fp)

# %%
_df = df[df["global_train_step"].notna()][:MAX_STEPS]
train_steps = _df["global_train_step"]
train_losses_depth_32 = _df["train_loss"]
train_losses_smoothed_depth_32 = gaussian_filter1d(train_losses_depth_32, sigma=SIGMA)

plt.plot(train_steps, train_losses_smoothed_depth_8, label="D=8")
plt.plot(train_steps, train_losses_smoothed_depth_12, label="D=12")
plt.plot(train_steps, train_losses_smoothed_depth_16, label="D=16")
plt.plot(train_steps, train_losses_smoothed_depth_20, label="D=20")
plt.plot(train_steps, train_losses_smoothed_depth_28, label="D=28")
plt.plot(train_steps, train_losses_smoothed_depth_32, label="D=32")

plt.xlabel("train_steps")
plt.ylabel("l1")
plt.title("Transformer Block Depth")
plt.grid()

# Add the legend here
plt.legend()
plt.show()

# %%
_df = df[df["global_val_step"].notna()]

val_steps = _df["global_val_step"].values
val_losses = _df["val_loss"].values
val_losses_smoothed = gaussian_filter1d(val_losses, sigma=SIGMA)

# find lowest point in the smoothed losses
min_index = np.argmin(val_losses_smoothed)
lowest_val_epoch = val_steps[min_index]
lowest_val_loss = val_losses_smoothed[min_index]

# plot smoothed loss
plt.plot(val_steps, val_losses_smoothed)
plt.xlabel("steps")
plt.ylabel("val_loss")
plt.title("Val Loss vs Epoch")
plt.grid(True)

# plot red dot at the lowest loss point
plt.plot(lowest_val_epoch, lowest_val_loss, 'ro', label='Min Loss')
 
# annotate lowest loss value on the figure
plt.annotate(f'Min Loss: {lowest_val_loss:.4f}',
             xy=(lowest_val_epoch, lowest_val_loss), 
             xytext=(lowest_val_epoch, lowest_val_loss), 
             arrowprops=dict(facecolor='black', arrowstyle='->'),
             ha='center')

plt.legend()
plt.show()

# %% [markdown]
# # **Surrogate Model Training**
# ***

# %%
import pandas as pd
from matplotlib import pyplot as plt

fp = "/playpen/mufan/levi/tianlong-chen-lab/material-super-resolution/__exps__/y-task-formulations/p(y | y_sparse)/6c. surrogate-train-runs/2025-02-02_06-10-31_surrogate-depth=8/results.csv"
df = pd.read_csv(fp)
df.head()

# %%
from matplotlib import pyplot as plt
from scipy.ndimage import gaussian_filter1d

SIGMA = 10

_df = df[df["global_train_step"].notna()]
train_steps = _df["global_train_step"]
train_losses = _df["train_surrogate_loss"]
train_losses_smoothed = gaussian_filter1d(train_losses, sigma=SIGMA)

plt.plot(train_steps, train_losses_smoothed)
plt.xlabel("epoch")
plt.ylabel("surrogate_train_loss")

plt.ylim(0, 1)

plt.title("Surrogate Training Loss vs # Epochs")
plt.grid()
plt.show()

# %%
SIGMA = 1

_df = df[df["global_train_step"].notna()]
train_steps = _df["global_train_step"]
train_losses = _df["train_denoising_loss"]
train_losses_smoothed = gaussian_filter1d(train_losses, sigma=SIGMA)

plt.plot(train_steps, train_losses_smoothed)
plt.xlabel("epoch")
plt.ylabel("train_denoising_loss")
plt.ylim(0, .01)

plt.title("Denoiser Training Loss vs # Epochs")
plt.grid()
plt.show()

# %%
SIGMA = 1

_df = df[df["global_val_step"].notna()]
train_steps = _df["global_val_step"]
train_losses = _df["val_denoising_loss"]
train_losses_smoothed = gaussian_filter1d(train_losses, sigma=SIGMA)

plt.plot(train_steps, train_losses_smoothed)
plt.xlabel("epoch")
plt.ylabel("train_denoising_loss")
plt.ylim(0, .01)

plt.title("Denoiser Val Loss vs # Epochs")
plt.grid()
plt.show()
