# %%
import numpy as np
import pandas as pd
from glob import glob

root_dir = "/playpen/mufan/levi/tianlong-chen-lab/material-super-resolution/__exps__/ablations/augmentations/_evals"
results = sorted(glob(root_dir + "/*/*.csv"))

for result in results:
    df = pd.read_csv(result)
    print("{" + result.split("/")[-2].split("{")[-1])
    print(np.array(df['psnr']).mean())
    print("------------------------")
# Out:
# {None}
# 45.223023090362545
# ------------------------
# {horizontal_flip, vertical_flip, random_rotation, elastic_transform}
# 46.97511595344543
# ------------------------
# {horizontal_flip, vertical_flip, random_rotation}
# 47.33294143295288
# ------------------------
# {horizontal_flip, vertical_flip}
# 46.65438270759582
# ------------------------
# {horizontal_flip, }
# 46.34607529258728
# ------------------------
