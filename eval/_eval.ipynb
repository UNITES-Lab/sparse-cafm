# %%
import pandas as pd

fp = r"/playpen/mufan/levi/tianlong-chen-lab/material-super-resolution/__exps__/y-task-formulations/6. p(y | y_sparse)/6b. evals/2025-01-24_14-36-40_ours-50%-sparse/results.csv"
df = pd.read_csv(fp)
df.head()

df["mae"].mean(), df["mse"].mean(), df["psnr"].mean(), df["ssim"].mean()
# Out:
# (0.11207521972772014,
#  0.07810481094078126,
#  20.73274487397802,
#  0.7910248230448546)
