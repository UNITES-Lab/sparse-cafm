# %%
import pandas as pd
fp = r"/playpen/mufan/levi/tianlong-chen-lab/material-super-resolution/__exps__/y-task-formulations/6. p(y | y_sparse)/6b. evals/2025-01-29_10-01-37_controlnet_sigmoid-eval-50%-sparse/results.csv"
df = pd.read_csv(fp)
len(df)
# Out:
# 1000

# %%
df["mae"].mean(), df["mse"].mean(), df["psnr"].mean(), df["ssim"].mean(), df["older"].mean()
# Out:
# (0.030410720793530303,
#  0.002061960886290714,
#  35.12793953895569,
#  0.7356883990466595,
#  0.43593275746840826)
