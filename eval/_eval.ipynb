# %%
import pandas as pd
fp = r"/playpen/mufan/levi/tianlong-chen-lab/material-super-resolution/__exps__/y-task-formulations/6. p(y | y_sparse)/6b. evals/2025-01-29_17-04-12_gpstruct-eval-50%-sparse/results.csv"
df = pd.read_csv(fp)
df.head()
# Out:
#    step       mae       mse       psnr      ssim     older  \
# 0     0  0.006621  0.000174  43.605457  0.969414  0.067256
# 1     1  0.008632  0.000280  41.551389  0.953829  0.585081
# 2     2  0.007025  0.000195  43.124860  0.966030  0.153787
# 3     3  0.006370  0.000164  43.880672  0.970871  0.253207
# 4     4  0.008320  0.000243  42.172453  0.957576  0.173688
#
#                                      celano_script_y  \
# 0  {'coverage_percentage': 3.936767578125, 'total...
# 1  {'coverage_percentage': 54.290771484375, 'tota...
# 2  {'coverage_percentage': 0.8544921875, 'total_l...
# 3  {'coverage_percentage': 0.45166015625, 'total_...
# 4  {'coverage_percentage': 71.5087890625, 'total_...
#
#                               celano_script_y_sparse
# 0  {'coverage_percentage': 3.13720703125, 'total_...
# 1  {'coverage_percentage': 52.9541015625, 'total_...
# 2  {'coverage_percentage': 0.567626953125, 'total...
# 3  {'coverage_percentage': 0.1953125, 'total_len_...
# ...

# %%
summary_stats = {
    "MAE": df["mae"].mean(),
    "MSE": df["mse"].mean(),
    "PSNR": df["psnr"].mean() - 6.02, # HACK: scale PSNR [-1, 1] -> [0, 1]
    "SSIM": df["ssim"].mean(),
    "OLDER": df["older"].mean(),
}
summary_str = "\n".join([f"{key}: {value:.6f}" for key, value in summary_stats.items()])
print("Stats:\n" + summary_str)
# Out:
# Stats:
# MAE: 0.009556
# MSE: 0.000414
# PSNR: 35.000716
# SSIM: 0.950169
# OLDER: 0.295267

# %%
def correct_psnr(val: float) -> float:
    return f"{(val - 6.02):.6f}"

correct_psnr(42.16350)
# Out:
# '36.143500'
