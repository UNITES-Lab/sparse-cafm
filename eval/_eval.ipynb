# %% [markdown]
# # **UNet**
# ***

# %%
import pandas as pd

fp = r"/playpen/mufan/levi/tianlong-chen-lab/material-super-resolution/__exps__/y-task-formulations/6. p(y | y_sparse)/6b. evals/2025-01-26_15-20-06_unet-revisted-50%-sparse/results.csv"
df = pd.read_csv(fp)
df.head()
# Out:
#    step       mae       mse       psnr      ssim     older  \
# 0     0  0.006396  0.000148  44.320969  0.975284  0.445190
# 1     1  0.007989  0.000222  42.561031  0.962630  0.495249
# 2     2  0.009141  0.000287  41.447479  0.956308  0.126675
# 3     3  0.008230  0.000243  42.163593  0.963323  0.177485
# 4     4  0.008293  0.000229  42.429619  0.961998  0.114415
#
#                                      celano_script_y  \
# 0  {'coverage_percentage': 3.936767578125, 'total...
# 1  {'coverage_percentage': 54.290771484375, 'tota...
# 2  {'coverage_percentage': 0.8544921875, 'total_l...
# 3  {'coverage_percentage': 0.45166015625, 'total_...
# 4  {'coverage_percentage': 71.5087890625, 'total_...
#
#                               celano_script_y_sparse
# 0  {'coverage_percentage': 3.3935546875, 'total_l...
# 1  {'coverage_percentage': 53.57666015625, 'total...
# 2  {'coverage_percentage': 0.79345703125, 'total_...
# 3  {'coverage_percentage': 0.335693359375, 'total...
# 4  {'coverage_percentage': 70.428466796875, 'tota...

# %%
df.iloc[0, ...]['celano_script_y']
# Out:
# "{'coverage_percentage': 3.936767578125, 'total_len_detected_curves': 25.799732642248273, 'total_len_detected_curves_without_boundary': -486.2002673577517, 'total_area_circular_shapes': 0.8966064453125, 'total_area_extended_shapes': 0.0, 'total_defect_area': 0.005472451448440552, 'num_circular_shapes': 69, 'num_extended_shapes': 0, 'num_curved_lines': 2, 'average_surface_current': -0.6243804362426886}"

# %%
df.iloc[0, ...]['celano_script_y_sparse']
# Out:
# "{'coverage_percentage': 3.3935546875, 'total_len_detected_curves': 22.186645325273275, 'total_len_detected_curves_without_boundary': -489.8133546747267, 'total_area_circular_shapes': 0.84814453125, 'total_area_extended_shapes': 0.065185546875, 'total_defect_area': 0.005574524402618408, 'num_circular_shapes': 62, 'num_extended_shapes': 1, 'num_curved_lines': 2, 'average_surface_current': -0.6372492533657237}"

# %%
df["mae"].mean(), df["mse"].mean(), df["psnr"].mean(), df["ssim"].mean(), df["older"].mean()
# Out:
# (0.00938889956660564,
#  0.00036351839526464123,
#  41.384538284301755,
#  0.9569134058952331,
#  0.2553939847894528)

# %% [markdown]
# # **SwinIR**
# ***

# %%
fp = r"/playpen/mufan/levi/tianlong-chen-lab/material-super-resolution/__exps__/y-task-formulations/6. p(y | y_sparse)/6b. evals/2025-01-27_08-44-53_swinir-revisted-50%-sparse/results.csv"
df = pd.read_csv(fp)
df["mae"].mean(), df["mse"].mean(), df["psnr"].mean(), df["ssim"].mean(), df["older"].mean()
# Out:
# (0.008221362766344052,
#  0.0002954508032416452,
#  42.30870325088501,
#  0.96319759786129,
#  0.2265768362567546)

# %%
# import numpy as np
# def get_mean_col(col):
#     arr = [float(s.split("tensor(")[-1].split(")")[0]) for s in col.dropna()]
#     return np.array(arr).mean()
# get_mean_col(df['val_l1']), get_mean_col(df['val_mse']), get_mean_col(df['val_ssim']), get_mean_col(df['val_psnr'])

# %% [markdown]
# # **Baseline**: Linear Interpolation
# ***

# %%
fp = r"/playpen/mufan/levi/tianlong-chen-lab/material-super-resolution/__exps__/y-task-formulations/6. p(y | y_sparse)/6b. evals/2025-01-26_14-44-33_linear-revisted-50%-sparse/results.csv"
df = pd.read_csv(fp)
df["mae"].mean(), df["mse"].mean(), df["psnr"].mean(), df["ssim"].mean(), df["older"].mean()
# Out:
# (0.008346188999712418,
#  0.0003068350731627533,
#  42.163504920959475,
#  0.9616674144268036,
#  0.2687830867962366)

# %%
df.iloc[0, ...]['celano_script_y']
# Out:
# "{'coverage_percentage': 3.936767578125, 'total_len_detected_curves': 25.799732642248273, 'total_len_detected_curves_without_boundary': -486.2002673577517, 'total_area_circular_shapes': 0.8966064453125, 'total_area_extended_shapes': 0.0, 'total_defect_area': 0.005472451448440552, 'num_circular_shapes': 69, 'num_extended_shapes': 0, 'num_curved_lines': 2, 'average_surface_current': -0.6243804362426886}"

# %%
df.iloc[0, ...]['celano_script_y_sparse']
# Out:
# "{'coverage_percentage': 3.50341796875, 'total_len_detected_curves': 22.634868633002043, 'total_len_detected_curves_without_boundary': -489.36513136699796, 'total_area_circular_shapes': 0.998291015625, 'total_area_extended_shapes': 0.0, 'total_defect_area': 0.006093084812164307, 'num_circular_shapes': 64, 'num_extended_shapes': 0, 'num_curved_lines': 2, 'average_surface_current': -0.6270079455639177}"
