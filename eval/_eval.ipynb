# %%
import pandas as pd
fp = r"/playpen/mufan/levi/tianlong-chen-lab/material-super-resolution/__exps__/y-task-formulations/6. p(y | y_sparse)/6b. evals/2025-02-05_08-36-17__swinir->unet.out/results.csv"
df = pd.read_csv(fp)
df.head()
# Out:
#    step       mae       mse       psnr      ssim     older  \
# 0     0  0.000761  0.000002  56.977642  0.999448  0.013663
# 1     1  0.002051  0.000010  49.812248  0.997458  0.751734
# 2     2  0.001547  0.000007  51.678207  0.997470  0.011218
# 3     3  0.001469  0.000006  51.953442  0.998000  0.420952
# 4     4  0.002466  0.000013  48.848106  0.996447  0.029157
#
#                                      celano_script_y  \
# 0  {'coverage_percentage': 3.936767578125, 'total...
# 1  {'coverage_percentage': 54.290771484375, 'tota...
# 2  {'coverage_percentage': 0.8544921875, 'total_l...
# 3  {'coverage_percentage': 0.45166015625, 'total_...
# 4  {'coverage_percentage': 71.5087890625, 'total_...
#
#                               celano_script_y_sparse
# 0  {'coverage_percentage': 4.083251953125, 'total...
# 1  {'coverage_percentage': 55.7373046875, 'total_...
# 2  {'coverage_percentage': 0.86669921875, 'total_...
# 3  {'coverage_percentage': 0.457763671875, 'total...
# ...

# %%
summary_stats = {
    "MAE": df["mae"].mean(),
    "MSE": df["mse"].mean(),
    "PSNR": df["psnr"].mean(),
    "SSIM": df["ssim"].mean(),
    "OLDER": df["older"].mean(),
}
summary_str = "\n".join([f"{key}: {value:.6f}" for key, value in summary_stats.items()])
print("Stats:\n" + summary_str)
# Out:
# Stats:
# MAE: 0.002154
# MSE: 0.000024
# PSNR: 49.974892
# SSIM: 0.995915
# OLDER: 0.135203
