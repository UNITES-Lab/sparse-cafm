# %%
import pandas as pd

fp = r"/playpen/mufan/levi/tianlong-chen-lab/material-super-resolution/__exps__/y-task-formulations/6. p(y | y_sparse)/6b. evals/2025-01-26_14-38-35_unet-norm-fixed-50%-sparse/results.csv"
df = pd.read_csv(fp)
df.head()
# Out:
#    step       mae       mse       psnr      ssim     older  \
# 0     0  0.006503  0.000153  44.168266  0.975293  0.459326
# 1     1  0.008225  0.000231  42.381386  0.962291  0.385070
# 2     2  0.006493  0.000158  44.036301  0.973520  0.068282
# 3     3  0.006129  0.000138  44.633682  0.975960  0.245232
# 4     4  0.008677  0.000248  42.076237  0.961154  0.459785
#
#                                      celano_script_y  \
# 0  {'coverage_percentage': 3.936767578125, 'total...
# 1  {'coverage_percentage': 54.290771484375, 'tota...
# 2  {'coverage_percentage': 0.8544921875, 'total_l...
# 3  {'coverage_percentage': 0.45166015625, 'total_...
# 4  {'coverage_percentage': 71.5087890625, 'total_...
#
#                               celano_script_y_sparse
# 0  {'coverage_percentage': 3.1982421875, 'total_l...
# 1  {'coverage_percentage': 52.2705078125, 'total_...
# 2  {'coverage_percentage': 0.78125, 'total_len_de...
# 3  {'coverage_percentage': 0.299072265625, 'total...
# 4  {'coverage_percentage': 69.622802734375, 'tota...

# %%
df.iloc[0, ...]['celano_script_y']
# Out:
# "{'coverage_percentage': 3.936767578125, 'total_len_detected_curves': 25.799732642248273, 'total_len_detected_curves_without_boundary': -486.2002673577517, 'total_area_circular_shapes': 0.8966064453125, 'total_area_extended_shapes': 0.0, 'total_defect_area': 0.005472451448440552, 'num_circular_shapes': 69, 'num_extended_shapes': 0, 'num_curved_lines': 2, 'average_surface_current': -0.6243804362426886}"

# %%
df.iloc[0, ...]['celano_script_y_sparse']
# Out:
# "{'coverage_percentage': 3.1982421875, 'total_len_detected_curves': 23.85177878662944, 'total_len_detected_curves_without_boundary': -488.14822121337056, 'total_area_circular_shapes': 0.7706298828125, 'total_area_extended_shapes': 0.1539306640625, 'total_defect_area': 0.005643069744110107, 'num_circular_shapes': 59, 'num_extended_shapes': 2, 'num_curved_lines': 2, 'average_surface_current': -0.6410131869749591}"

# %%
df["mae"].mean(), df["mse"].mean(), df["psnr"].mean(), df["ssim"].mean(), df["older"].mean()
# Out:
# (0.008993640269832142,
#  0.00035627184739482826,
#  41.72172651429107,
#  0.959497695815736,
#  0.2719569929995234)

# %%
# import numpy as np
# def get_mean_col(col):
#     arr = [float(s.split("tensor(")[-1].split(")")[0]) for s in col.dropna()]
#     return np.array(arr).mean()
# get_mean_col(df['val_l1']), get_mean_col(df['val_mse']), get_mean_col(df['val_ssim']), get_mean_col(df['val_psnr'])

# %%
fp = r"/playpen/mufan/levi/tianlong-chen-lab/material-super-resolution/__exps__/y-task-formulations/6. p(y | y_sparse)/6b. evals/2025-01-25_14-56-23_linear-50%-sparse/results.csv"
df = pd.read_csv(fp)
df["mae"].mean(), df["mse"].mean(), df["psnr"].mean(), df["ssim"].mean(), df["older"].mean()
# Out:
# (0.07345386963337656,
#  0.023766101663000833,
#  23.272975742340087,
#  0.7855588553547859,
#  0.2663840462540761)

# %%
df.iloc[0, ...]['celano_script_y']
# Out:
# "{'coverage_percentage': 2.40478515625, 'total_len_detected_curves': 27.137201065197587, 'total_len_detected_curves_without_boundary': -484.8627989348024, 'total_area_circular_shapes': 0.8565673828125, 'total_area_extended_shapes': 0.0, 'total_defect_area': 0.00522807240486145, 'num_circular_shapes': 68, 'num_extended_shapes': 0, 'num_curved_lines': 2, 'average_surface_current': -1.71717696e+17}"

# %%
df.iloc[0, ...]['celano_script_y_sparse']
# Out:
# "{'coverage_percentage': 2.069091796875, 'total_len_detected_curves': 22.64781280606985, 'total_len_detected_curves_without_boundary': -489.35218719393015, 'total_area_circular_shapes': 1.0001220703125, 'total_area_extended_shapes': 0.0, 'total_defect_area': 0.006104260683059692, 'num_circular_shapes': 64, 'num_extended_shapes': 0, 'num_curved_lines': 2, 'average_surface_current': -1.72302176e+17}"
