# %%
import pandas as pd
fp = r"/playpen/mufan/levi/tianlong-chen-lab/material-super-resolution/__exps__/y-task-formulations/p(y | y_sparse)/6b. evals/2025-02-06_16-08-30_swinir_p(y | X_sparse)/results.csv"
df = pd.read_csv(fp)
df.head()
# Out:
#    step       mae       mse       psnr      ssim     older  \
# 0     0  0.054866  0.005125  22.903030  0.750672  0.362030
# 1     1  0.052164  0.004017  23.960472  0.683277  0.365525
# 2     2  0.051859  0.004035  23.941029  0.694347  0.413793
# 3     3  0.073173  0.007907  21.019676  0.714852  0.434810
# 4     4  0.064769  0.005652  22.477863  0.672403  0.502291
#
#                                      celano_script_y  \
# 0  {'coverage_percentage': 3.936767578125, 'total...
# 1  {'coverage_percentage': 54.290771484375, 'tota...
# 2  {'coverage_percentage': 0.8544921875, 'total_l...
# 3  {'coverage_percentage': 0.45166015625, 'total_...
# 4  {'coverage_percentage': 71.5087890625, 'total_...
#
#                               celano_script_y_sparse
# 0  {'coverage_percentage': 24.395751953125, 'tota...
# 1  {'coverage_percentage': 80.474853515625, 'tota...
# 2  {'coverage_percentage': 12.384033203125, 'tota...
# 3  {'coverage_percentage': 28.52783203125, 'total...
# ...

# %%
summary_stats = {
    "MAE": df["mae"].mean(),
    "MSE": df["mse"].mean(),
    "PSNR": df["psnr"].mean() - 6.02, # HACK: scale PSNR [-1, 1] -> [0, 1]
    "SSIM": df["ssim"].mean(),
    "OLDER": df["older"].mean(),
}
summary_str = "\n".join([f"{key}: {value:.6f}" for key, value in summary_stats.items()])
print("Stats:\n" + summary_str)
# Out:
# Stats:
# MAE: 0.085164
# MSE: 0.012290
# PSNR: 14.613693
# SSIM: 0.664221
# OLDER: 1.380398
