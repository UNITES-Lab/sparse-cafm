# %%
import os
import pandas as pd
from glob import glob

evals_dir = "/playpen/mufan/levi/tianlong-chen-lab/material-super-resolution/__exps__/y-task-formulations/p(y | y_sparse)/b. evals"
dirs = glob(f"{evals_dir}/*02-11*"); dirs

dirs.sort()

# %%
import matplotlib.pyplot as plt

exp_names = [s.split("02-10_")[-1] for s in dirs]; exp_names
exp_results = [glob(d + "/*.csv")[0] for d in dirs]; exp_results

for name, result in zip(exp_names, exp_results):
    assert name in result
    df = pd.read_csv(result)
    summary_stats = {
    "MAE": df["mae"].mean(),
    "MSE": df["mse"].mean(),
    "PSNR": df["psnr"].mean(),
    "SSIM": df["ssim"].mean(),
    "OLDER": df["older"].mean(),
    }
    summary_str = "\n".join([f"{key}: {value:.6f}" for key, value in summary_stats.items()])
    print(f"{name} stats:\n" + summary_str)
    print("------------------------------")
# Out:
# /playpen/mufan/levi/tianlong-chen-lab/material-super-resolution/__exps__/y-task-formulations/p(y | y_sparse)/b. evals/2025-02-11_08-49-22_swinir-loss=OLDER-Perceptual(raw-out, y) stats:
# MAE: 0.008555
# MSE: 0.000313
# PSNR: 35.993839
# SSIM: 0.912060
# OLDER: 0.314681
# ------------------------------
# /playpen/mufan/levi/tianlong-chen-lab/material-super-resolution/__exps__/y-task-formulations/p(y | y_sparse)/b. evals/2025-02-11_08-49-22_swinir-loss=OLDER-Perceptual(raw-out, y)+L1(raw-out, y) stats:
# MAE: 0.008363
# MSE: 0.000303
# PSNR: 36.221245
# SSIM: 0.916445
# OLDER: 0.309160
# ------------------------------
