# %%
import os
import pandas as pd
from glob import glob

evals_dir = "/playpen/mufan/levi/tianlong-chen-lab/material-super-resolution/__exps__/y-task-formulations/p(y | y_sparse)/b. evals"
dirs = glob(f"{evals_dir}/*02-13*"); dirs

dirs.sort()

# %%
import matplotlib.pyplot as plt

exp_names = [s.split("02-13_")[-1] for s in dirs]; exp_names
exp_results = [glob(d + "/*.csv")[0] for d in dirs]; exp_results

for name, result in zip(exp_names, exp_results):
    assert name in result
    df = pd.read_csv(result)
    summary_stats = {
    "MAE": df["mae"].mean(),
    "MSE": df["mse"].mean(),
    "PSNR": df["psnr"].mean(),
    "SSIM": df["ssim"].mean(),
    "OLDER": df["older"].mean(),
    }
    summary_str = "\n".join([f"{key}: {value:.6f}" for key, value in summary_stats.items()])
    print(f"{name} stats:\n" + summary_str)
    print("------------------------------")
# Out:
# 16-43-14_SwinIR-loss=OLDER-W-Perceptual-VGG-aug=F-Multi-Layer+L1(raw-out, y)-lambda=1e-0 stats:
# MAE: 0.008171
# MSE: 0.000301
# PSNR: 36.328059
# SSIM: 0.918187
# OLDER: 0.294367
# ------------------------------
# 16-43-14_SwinIR-loss=OLDER-W-Perceptual-VGG-aug=F-Multi-Layer+L1(raw-out, y)-lambda=1e-1 stats:
# MAE: 0.008138
# MSE: 0.000302
# PSNR: 36.376718
# SSIM: 0.918568
# OLDER: 0.310330
# ------------------------------
# 16-43-14_SwinIR-loss=OLDER-W-Perceptual-VGG-aug=F-Multi-Layer+L1(raw-out, y)-lambda=1e-2 stats:
# MAE: 0.007971
# MSE: 0.000286
# PSNR: 36.489637
# SSIM: 0.920843
# OLDER: 0.292814
# ------------------------------
# 16-43-14_SwinIR-loss=OLDER-W-Perceptual-VGG-aug=F-Multi-Layer+L1(raw-out, y)-lambda=1e-4 stats:
# MAE: 0.008021
# MSE: 0.000286
# PSNR: 36.453383
# SSIM: 0.920644
# OLDER: 0.276543
# ------------------------------
# 16-43-14_SwinIR-loss=OLDER-W-Perceptual-VGG-aug=F-Multi-Layer+L1(raw-out, y)-lambda=1e-5 stats:
# MAE: 0.008006
# MSE: 0.000286
# PSNR: 36.478518
# SSIM: 0.920655
# OLDER: 0.284511
# ------------------------------
# 16-43-14_SwinIR-loss=OLDER-W-Perceptual-VGG-aug=F-Multi-Layer+L1(raw-out, y)-lambda=1e-6 stats:
# MAE: 0.008061
# MSE: 0.000291
# PSNR: 36.458013
# SSIM: 0.920209
# OLDER: 0.277552
# ------------------------------
# 16-43-14_SwinIR-loss=OLDER-W-Perceptual-VGG-aug=F-Multi-Layer+L1(raw-out, y)-lambda=1e-7 stats:
# MAE: 0.007969
# MSE: 0.000283
# PSNR: 36.524915
# SSIM: 0.921251
# OLDER: 0.296401
# ------------------------------
# 16-43-14_SwinIR-loss=OLDER-W-Perceptual-VGG-aug=F-Multi-Layer+L1(raw-out, y)-lambda=1e-8 stats:
# MAE: 0.008028
# MSE: 0.000291
# PSNR: 36.476601
# SSIM: 0.920415
# OLDER: 0.287775
# ------------------------------
# 16-43-15_SwinIR-loss=OLDER-W-Perceptual-VGG-aug=F-Multi-Layer+L1(raw-out, y)-lambda=1e-3 stats:
# MAE: 0.007993
# MSE: 0.000282
# PSNR: 36.504242
# SSIM: 0.920930
# OLDER: 0.282697
# ------------------------------
