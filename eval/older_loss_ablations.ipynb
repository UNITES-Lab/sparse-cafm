# %%
import os
import pandas as pd
from glob import glob

evals_dir = "/playpen/mufan/levi/tianlong-chen-lab/material-super-resolution/__exps__/y-task-formulations/p(y | y_sparse)/b. evals"
dirs = glob(f"{evals_dir}/*02-09*"); dirs

dirs.sort()

# %%
import matplotlib.pyplot as plt

exp_names = [s.split("02-09_")[-1] for s in dirs]; exp_names
exp_results = [glob(d + "/*.csv")[0] for d in dirs]; exp_results

for name, result in zip(exp_names, exp_results):
    assert name in result
    df = pd.read_csv(result)
    summary_stats = {
    "MAE": df["mae"].mean(),
    "MSE": df["mse"].mean(),
    "PSNR": df["psnr"].mean(),
    "SSIM": df["ssim"].mean(),
    "OLDER": df["older"].mean(),
    }
    summary_str = "\n".join([f"{key}: {value:.6f}" for key, value in summary_stats.items()])
    print(f"{name} stats:\n" + summary_str)
    print("------------------------------")
# Out:
# 11-47-18_swinir_L1-BEST stats:
# MAE: 0.008005
# MSE: 0.000285
# PSNR: 36.495273
# SSIM: 0.921149
# OLDER: 0.273071
# ------------------------------
# 11-47-18_swinir_OLDER+L1-BEST stats:
# MAE: 0.009337
# MSE: 0.000364
# PSNR: 35.236049
# SSIM: 0.895983
# OLDER: 0.301482
# ------------------------------
# 11-47-18_swinir_OLDER+L1-LATEST stats:
# MAE: 0.009458
# MSE: 0.000372
# PSNR: 35.208173
# SSIM: 0.895411
# OLDER: 0.309249
# ------------------------------
# 11-47-19_swinir_L1-LATEST stats:
# MAE: 0.008530
# MSE: 0.000323
# PSNR: 35.952719
# SSIM: 0.912138
# OLDER: 0.288603
# ------------------------------
# 11-47-19_swinir_OLDER-BEST stats:
# MAE: 0.009593
# MSE: 0.000392
# PSNR: 35.031296
# SSIM: 0.889574
# OLDER: 0.313272
# ------------------------------
# 11-47-19_swinir_OLDER-LATEST stats:
# MAE: 0.009707
# MSE: 0.000396
# PSNR: 34.972266
# SSIM: 0.889973
# OLDER: 0.335499
# ------------------------------
# 12-08-49_linear-interpolation-baseline stats:
# MAE: 0.008346
# MSE: 0.000307
# PSNR: 36.142903
# SSIM: 0.916031
# OLDER: 0.321020
# ------------------------------
# 12-15-27_bicubic_interpolation-baseline stats:
# MAE: 0.009443
# MSE: 0.000402
# PSNR: 34.925657
# SSIM: 0.894117
# OLDER: 0.283741
# ------------------------------
# 12-55-51_nn_interpolation-baseline stats:
# MAE: 0.010868
# MSE: 0.000572
# PSNR: 33.442869
# SSIM: 0.864599
# OLDER: 0.283792
# ------------------------------
