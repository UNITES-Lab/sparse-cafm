# %%
import os
import pandas as pd
from glob import glob

evals_dir = "/playpen/mufan/levi/tianlong-chen-lab/material-super-resolution/__exps__/y-task-formulations/p(y | y_sparse)/b. evals"
dirs = glob(f"{evals_dir}/*02-10*"); dirs

dirs.sort()

# %%
import matplotlib.pyplot as plt

exp_names = [s.split("02-10_")[-1] for s in dirs]; exp_names
exp_results = [glob(d + "/*.csv")[0] for d in dirs]; exp_results

for name, result in zip(exp_names, exp_results):
    assert name in result
    df = pd.read_csv(result)
    summary_stats = {
    "MAE": df["mae"].mean(),
    "MSE": df["mse"].mean(),
    "PSNR": df["psnr"].mean(),
    "SSIM": df["ssim"].mean(),
    "OLDER": df["older"].mean(),
    }
    summary_str = "\n".join([f"{key}: {value:.6f}" for key, value in summary_stats.items()])
    print(f"{name} stats:\n" + summary_str)
    print("------------------------------")
# Out:
# 09-48-05_swinir-loss=L1(raw_out,y)-surrogate_mode=train stats:
# MAE: 0.008515
# MSE: 0.000321
# PSNR: 35.943936
# SSIM: 0.912658
# OLDER: 0.296045
# ------------------------------
# 09-48-05_swinir-loss=L1(y_hat, y)-surrogate_mode=eval stats:
# MAE: 0.008669
# MSE: 0.000330
# PSNR: 35.800170
# SSIM: 0.908908
# OLDER: 0.298646
# ------------------------------
# 09-48-05_swinir-loss=OLDER(raw_out,y)-surrogate_mode=train stats:
# MAE: nan
# MSE: nan
# PSNR: nan
# SSIM: nan
# OLDER: nan
# ------------------------------
# 09-48-05_swinir-loss=OLDER(y_hat, y)-surrogate_mode=eval stats:
# MAE: 0.009504
# MSE: 0.000358
# PSNR: 35.146858
# SSIM: 0.890359
# OLDER: 0.328883
# ------------------------------
# 09-48-05_swinir-loss=OLDER+L1(raw_out,y)-surrogate_mode=train stats:
# MAE: 0.009841
# MSE: 0.000416
# PSNR: 34.597181
# SSIM: 0.901183
# OLDER: 0.346713
# ------------------------------
# 09-48-05_swinir-loss=OLDER+L1(y_hat, y)-surrogate_mode=eval stats:
# MAE: 0.009365
# MSE: 0.000381
# PSNR: 35.292205
# SSIM: 0.897745
# OLDER: 0.286130
# ------------------------------
