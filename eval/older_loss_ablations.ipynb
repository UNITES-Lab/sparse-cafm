# %%
import pandas as pd
from glob import glob

evals_dir = "/playpen/mufan/levi/tianlong-chen-lab/material-super-resolution/__exps__/y-task-formulations/p(y | y_sparse)/b. evals"
dirs = glob(f"{evals_dir}/*02-20*")
dirs.sort()

# %%
import matplotlib.pyplot as plt

exp_names = [s.split("02-20_")[-1] for s in dirs]; exp_names
exp_results = [glob(d + "/*.csv")[0] for d in dirs]; exp_results

for name, result in zip(exp_names, exp_results):
    assert name in result
    df = pd.read_csv(result)
    summary_stats = {
    "MAE": df["mae"].mean(),
    "MSE": df["mse"].mean(),
    "PSNR": df["psnr"].mean(),
    "SSIM": df["ssim"].mean(),
    "OLDER": df["older"].mean(),
    }
    summary_str = "\n".join([f"{key}: {value:.6f}" for key, value in summary_stats.items()])
    print(f"{name} stats:\n" + summary_str)
    print("------------------------------")
# Out:
# 12-08-59_SwinIR-loss=OLDER-Perceptual-VGG-Multi-Layer+L1(raw-out, y)-lambda=1e-1 stats:
# MAE: 0.013610
# MSE: 0.000790
# PSNR: 31.668624
# SSIM: 0.860773
# OLDER: 0.360406
# ------------------------------
# 12-09-00_SwinIR-loss=OLDER-Perceptual-VGG-19(raw-out, y)-vgg_layer=11 stats:
# MAE: 0.011532
# MSE: 0.000506
# PSNR: 33.570943
# SSIM: 0.881505
# OLDER: 0.277988
# ------------------------------
# 12-09-00_SwinIR-loss=OLDER-Perceptual-VGG-19(raw-out, y)-vgg_layer=24 stats:
# MAE: 0.015704
# MSE: 0.000762
# PSNR: 31.413133
# SSIM: 0.823401
# OLDER: 0.296815
# ------------------------------
# 12-09-00_SwinIR-loss=OLDER-Perceptual-VGG-19(raw-out, y)-vgg_layer=37 stats:
# MAE: 0.016749
# MSE: 0.000847
# PSNR: 30.955722
# SSIM: 0.811138
# OLDER: 0.290829
# ------------------------------
# 12-09-00_SwinIR-loss=OLDER-Perceptual-VGG-19(raw-out, y)-vgg_layer=4 stats:
# MAE: 0.009918
# MSE: 0.000432
# PSNR: 34.643838
# SSIM: 0.902697
# OLDER: 0.248309
# ------------------------------
# 12-09-00_SwinIR-loss=OLDER-Perceptual-VGG-19(raw-out, y)-vgg_layer=50 stats:
# MAE: 0.021938
# MSE: 0.001317
# PSNR: 29.045067
# SSIM: 0.745196
# OLDER: 0.329418
# ------------------------------
# 12-09-00_SwinIR-loss=OLDER-Perceptual-VGG-Multi-Layer+L1(raw-out, y)-lambda=1e-0 stats:
# MAE: 0.011803
# MSE: 0.000615
# PSNR: 32.980227
# SSIM: 0.882627
# OLDER: 0.315233
# ------------------------------
# 12-09-00_SwinIR-loss=OLDER-Perceptual-VGG-Multi-Layer+L1(raw-out, y)-lambda=1e-3 stats:
# MAE: 0.014167
# MSE: 0.000826
# PSNR: 31.487684
# SSIM: 0.847443
# OLDER: 0.370033
# ------------------------------
# 12-09-00_SwinIR-loss=OLDER-Perceptual-VGG-Multi-Layer+L1(raw-out, y)-lambda=1e-4 stats:
# MAE: 0.012154
# MSE: 0.000588
# PSNR: 32.975195
# SSIM: 0.872477
# OLDER: 0.314437
# ------------------------------
# 12-09-00_SwinIR-loss=OLDER-Perceptual-VGG-Multi-Layer+L1(raw-out, y)-lambda=1e-5 stats:
# MAE: 0.010543
# MSE: 0.000485
# PSNR: 34.150194
# SSIM: 0.895179
# OLDER: 0.308916
# ------------------------------
# 12-09-00_SwinIR-loss=OLDER-Perceptual-VGG-Multi-Layer+L1(raw-out, y)-lambda=1e-6 stats:
# MAE: 0.011246
# MSE: 0.000523
# PSNR: 33.629646
# SSIM: 0.886565
# OLDER: 0.303349
# ------------------------------
# 12-09-00_SwinIR-loss=OLDER-Perceptual-VGG-Multi-Layer+L1(raw-out, y)-lambda=1e-7 stats:
# MAE: 0.010915
# MSE: 0.000509
# PSNR: 33.761628
# SSIM: 0.889803
# OLDER: 0.315321
# ------------------------------
# 12-09-00_SwinIR-loss=OLDER-Perceptual-VGG-Multi-Layer+L1(raw-out, y)-lambda=1e-8 stats:
# MAE: 0.013770
# MSE: 0.000812
# PSNR: 31.571631
# SSIM: 0.856667
# OLDER: 0.330961
# ------------------------------
