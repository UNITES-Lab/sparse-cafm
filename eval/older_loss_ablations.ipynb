# %%
import os
import pandas as pd
from glob import glob

evals_dir = "/playpen/mufan/levi/tianlong-chen-lab/material-super-resolution/__exps__/y-task-formulations/p(y | y_sparse)/b. evals"
dirs = glob(f"{evals_dir}/*02-11*"); dirs

dirs.sort()

# %%
import matplotlib.pyplot as plt

exp_names = [s.split("02-11_")[-1] for s in dirs]; exp_names
exp_results = [glob(d + "/*.csv")[0] for d in dirs]; exp_results

for name, result in zip(exp_names, exp_results):
    assert name in result
    df = pd.read_csv(result)
    summary_stats = {
    "MAE": df["mae"].mean(),
    "MSE": df["mse"].mean(),
    "PSNR": df["psnr"].mean(),
    "SSIM": df["ssim"].mean(),
    "OLDER": df["older"].mean(),
    }
    summary_str = "\n".join([f"{key}: {value:.6f}" for key, value in summary_stats.items()])
    print(f"{name} stats:\n" + summary_str)
    print("------------------------------")
# Out:
# 08-49-22_swinir-loss=OLDER-Perceptual(raw-out, y) stats:
# MAE: 0.008555
# MSE: 0.000313
# PSNR: 35.993839
# SSIM: 0.912060
# OLDER: 0.314681
# ------------------------------
# 08-49-22_swinir-loss=OLDER-Perceptual(raw-out, y)+L1(raw-out, y) stats:
# MAE: 0.008363
# MSE: 0.000303
# PSNR: 36.221245
# SSIM: 0.916445
# OLDER: 0.309160
# ------------------------------
# 13-19-31_swinir-loss=OLDER-Perceptual+L1(raw-out, y)-lambda=1e-6 stats:
# MAE: 0.008084
# MSE: 0.000291
# PSNR: 36.356832
# SSIM: 0.919776
# OLDER: 0.269153
# ------------------------------
# 13-19-32_swinir-loss=OLDER-Perceptual+L1(raw-out, y)-lambda=1e-1 stats:
# MAE: 0.008166
# MSE: 0.000298
# PSNR: 36.327658
# SSIM: 0.917839
# OLDER: 0.282329
# ------------------------------
# 13-19-32_swinir-loss=OLDER-Perceptual+L1(raw-out, y)-lambda=1e-2 stats:
# MAE: 0.008074
# MSE: 0.000297
# PSNR: 36.384279
# SSIM: 0.919942
# OLDER: 0.274630
# ------------------------------
# 13-19-32_swinir-loss=OLDER-Perceptual+L1(raw-out, y)-lambda=1e-3 stats:
# MAE: 0.007984
# MSE: 0.000281
# PSNR: 36.525715
# SSIM: 0.921371
# OLDER: 0.285549
# ------------------------------
# 13-19-32_swinir-loss=OLDER-Perceptual+L1(raw-out, y)-lambda=1e-4 stats:
# MAE: 0.008053
# MSE: 0.000290
# PSNR: 36.400508
# SSIM: 0.919981
# OLDER: 0.271082
# ------------------------------
# 13-19-32_swinir-loss=OLDER-Perceptual+L1(raw-out, y)-lambda=1e-5 stats:
# MAE: 0.008108
# MSE: 0.000293
# PSNR: 36.322780
# SSIM: 0.919809
# OLDER: 0.300225
# ------------------------------
# 13-19-32_swinir-loss=OLDER-Perceptual+L1(raw-out, y)-lambda=1e-7 stats:
# MAE: 0.008088
# MSE: 0.000290
# PSNR: 36.397270
# SSIM: 0.920099
# OLDER: 0.272675
# ------------------------------
# 17-23-29_swinir-loss=OLDER-Perceptual+L1(raw-out, y)-lambda=1e-1 stats:
# MAE: 0.008272
# MSE: 0.000315
# PSNR: 36.143562
# SSIM: 0.916143
# OLDER: 0.295082
# ------------------------------
# 17-23-29_swinir-loss=OLDER-Perceptual+L1(raw-out, y)-lambda=1e-2 stats:
# MAE: 0.008074
# MSE: 0.000297
# PSNR: 36.384279
# SSIM: 0.919942
# OLDER: 0.274630
# ------------------------------
# 17-23-30_swinir-loss=OLDER-Perceptual+L1(raw-out, y)-lambda=1e-3 stats:
# MAE: 0.007984
# MSE: 0.000281
# PSNR: 36.525715
# SSIM: 0.921371
# OLDER: 0.285549
# ------------------------------
# 17-23-30_swinir-loss=OLDER-Perceptual+L1(raw-out, y)-lambda=1e-4 stats:
# MAE: 0.008053
# MSE: 0.000290
# PSNR: 36.400508
# SSIM: 0.919981
# OLDER: 0.271082
# ------------------------------
# 17-23-30_swinir-loss=OLDER-Perceptual+L1(raw-out, y)-lambda=1e-5 stats:
# MAE: 0.008108
# MSE: 0.000293
# PSNR: 36.322780
# SSIM: 0.919809
# OLDER: 0.300225
# ------------------------------
# 17-23-30_swinir-loss=OLDER-Perceptual+L1(raw-out, y)-lambda=1e-6 stats:
# MAE: 0.008212
# MSE: 0.000302
# PSNR: 36.208039
# SSIM: 0.917466
# OLDER: 0.262986
# ------------------------------
# 17-23-30_swinir-loss=OLDER-Perceptual+L1(raw-out, y)-lambda=1e-7 stats:
# MAE: 0.008301
# MSE: 0.000307
# PSNR: 36.119314
# SSIM: 0.915362
# OLDER: 0.296701
# ------------------------------
# 17-39-07_swinir-loss=OLDER-Perceptual-Multi-Layer+L1(raw-out, y)-lambda=1e-0 stats:
# MAE: 0.008280
# MSE: 0.000312
# PSNR: 36.216318
# SSIM: 0.916176
# OLDER: 0.306559
# ------------------------------
